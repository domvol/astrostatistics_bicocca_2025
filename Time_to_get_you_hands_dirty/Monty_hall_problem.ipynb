# %% [markdown]
# # Monty Hall problem

# %%
import numpy as np

trial = []
win_cons = 0
lose_cons = 0
win_swi = 0
lose_swi = 0
win_new = 0
lose_new = 0
trials = 10000

for i in range(trials):
    doors = np.zeros(3, dtype=int)
    doors[np.random.randint(0, 3)] = 1
    trial.append(doors)
    
for doors in trial:
    # Use randint instead of choice for selecting door index
    conservative_choice = np.random.randint(0, 3)
    if doors[conservative_choice] == 1:
        win_cons += 1
    else:
        lose_cons += 1

    # Get available doors that have goats and weren't chosen
    available_doors = [i for i in range(3) if doors[i] == 0 and i != conservative_choice]   #defined available_doors with list comprehension
    opened_door = np.random.choice(available_doors)                          #use random.choice to select a door to open
    
    # The remaining door is the one not chosen and not opened
    other_doors = [i for i in range(3) if i != opened_door and i != conservative_choice]  #defined other_doors with list comprehension
    switcher = other_doors[0]                           #changed this to use the first element of other_doors
    
    if doors[switcher] == 1:                #
        win_swi += 1
    else:
        lose_swi += 1

    closed_doors = [conservative_choice, other_doors[0]] 
    newcomer = np.random.choice(closed_doors)
    if doors[newcomer] == 1:
        win_new += 1
    else:
        lose_new += 1

print(f"Conservative player: Win percentage: {(win_cons*100)/trials}%")
print(f"Switcher player: Win percentage: {(win_swi*100)/trials}%")
print(f"Newcomer player: Win percentage: {(win_new*100)/trials}%")
# Out:
# Conservative player: Win percentage: 33.03%
# Switcher player: Win percentage: 66.97%
# Newcomer player: Win percentage: 50.67%

# %% [markdown]
# ## Monty Hall for N doors and p hints

# %%
import numpy as np
import random
from tqdm import tqdm

trial = []
win_cons = 0
lose_cons = 0
win_swi = 0
lose_swi = 0
win_new = 0
lose_new = 0
trials = 10000
num_doors = 100                # N doors
doors_to_open = 95             # p doors to open
for i in range(trials):
    doors = np.zeros(num_doors, dtype=int)      # array of length 3 with all zeros
    doors[np.random.randint(0, num_doors)] = 1  # assign the value 1 to a random position in the array
    trial.append(doors)                 # make a list of arrays with the various "draws"
    
for doors in trial:                     # check the number of wins without switching
    conservative_choice = np.random.choice(doors)
    if doors[conservative_choice] == 1:        # if the chosen door (first choice) is equal to the door with the car (1)
        win_cons += 1                      
    else:
        lose_cons += 1
    
    available_doors = [i for i in range(num_doors) if doors[i] == 0]   # make a list of indices where there are goats (0)
    opened_N_door = np.random.choice(available_doors, size=doors_to_open, replace=False)          # open N doors where there is a goat (choose the index that points to a 0)
    other_doors = [i for i in range(num_doors) if i not in opened_N_door and i != conservative_choice] # list of indices that are neither chosen nor opened by the host

    switcher = other_doors[0]                   # switch door by choosing the only available index
    if doors[switcher] == 1:      # if the chosen door (second choice) is equal to the door with the car (1)
        win_swi += 1                      
    else:
        lose_swi += 1
    closed_doors = [conservative_choice]+other_doors  # list of indices that are either chosen or not opened by the host
    newcomer = np.random.choice(closed_doors)  # choose a door at random from the two remaining doors
    if doors[newcomer] == 1:  
        win_new += 1                      
    else:
        lose_new += 1

print(f"Conservative player: Win percentage: {(win_cons*100)/trials}%")
print(f"Switcher player: Win percentage: {(win_swi*100)/trials}%")
print(f"Newcomer player: Win percentage: {(win_new*100)/trials}%")
# Out:
# Conservative player: Win percentage: 0.96%
# Switcher player: Win percentage: 20.17%
# Newcomer player: Win percentage: 17.75%

# %% [markdown]
# ## Monty hall varying p

# %%
import numpy as np
import matplotlib.pyplot as plt

trials = 1000
num_doors = 10
results = []

for doors_to_open in range(num_doors-1):
    # Reset counters for each number of doors to open
    win_cons = 0
    lose_cons = 0
    win_swi = 0
    lose_swi = 0
    win_new = 0
    lose_new = 0
    trial = []  # Reset trial list
    
    # Generate new trials
    for i in range(trials):
        doors = np.zeros(num_doors, dtype=int)
        doors[np.random.randint(0, num_doors)] = 1
        trial.append(doors)
    
    # Run the game for each trial
    for doors in trial:
        conservative_choice = np.random.randint(0, num_doors)  # Use randint instead of choice
        if doors[conservative_choice] == 1:
            win_cons += 1
        else:
            lose_cons += 1
    
        available_doors = [i for i in range(num_doors) if doors[i] == 0 and i != conservative_choice]
        opened_N_door = np.random.choice(available_doors, size=doors_to_open, replace=False)
        other_doors = [i for i in range(num_doors) if i not in opened_N_door and i != conservative_choice]
        closed_doors = [conservative_choice] + other_doors
        if len(other_doors) > 0:  # Make sure there are doors left to switch to
            switcher = other_doors[0]
            if doors[switcher] == 1:
                win_swi += 1
            else:
                lose_swi += 1

        newcomer = np.random.choice(closed_doors)  # Use randint instead of choice
        if doors[newcomer] == 1:
            win_new += 1
        else:
            lose_new += 1
    
    # Add results only once per doors_to_open value
    results.append([
        [doors_to_open, (win_cons*100)/trials, (lose_cons*100)/trials],
        [doors_to_open, (win_swi*100)/trials, (lose_swi*100)/trials],
        [doors_to_open, (win_new*100)/trials, (lose_new*100)/trials]
    ])

# Convert results to a numpy array for easier manipulation
results_array = np.array(results)

# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))

for i, player_type in enumerate(['Conservative', 'Switcher', 'Newcomer']):
    ax.plot(results_array[:, i, 0], results_array[:, i, 1], label=f'{player_type} Win %')
ax.set_title('Win and Lose percentages by player type and number of doors opened')
ax.set_xlabel('Number of doors opened')
ax.set_ylabel('Percentage')
ax.legend()
plt.show()

# %% [markdown]
# ## Monty hall varying N

# %%
import numpy as np

import matplotlib.pyplot as plt

trials = 1000
max_doors = 100
results = []

for num_doors in range(3, max_doors + 1, 10):
    doors_to_open = num_doors - 2  # Open all but two doors
    win_cons = 0
    lose_cons = 0
    win_swi = 0
    lose_swi = 0
    win_new = 0
    lose_new = 0
    trial = []
    
    for i in range(trials):
        doors = np.zeros(num_doors, dtype=int)
        doors[np.random.randint(0, num_doors)] = 1
        trial.append(doors)
    
    for doors in trial:
        conservative_choice = np.random.randint(0, num_doors)
        if doors[conservative_choice] == 1:
            win_cons += 1
        else:
            lose_cons += 1
    
        available_doors = [i for i in range(num_doors) if doors[i] == 0 and i != conservative_choice]
        opened_N_door = np.random.choice(available_doors, size=doors_to_open, replace=False)
        other_doors = [i for i in range(num_doors) if i not in opened_N_door and i != conservative_choice]
        closed_doors = [conservative_choice] + other_doors
        if len(other_doors) > 0:
            switcher = other_doors[0]
            if doors[switcher] == 1:
                win_swi += 1
            else:
                lose_swi += 1

        newcomer = np.random.choice(closed_doors)
        if doors[newcomer] == 1:
            win_new += 1
        else:
            lose_new += 1
    
    results.append([
        [num_doors, (win_cons*100)/trials, (lose_cons*100)/trials],
        [num_doors, (win_swi*100)/trials, (lose_swi*100)/trials],
        [num_doors, (win_new*100)/trials, (lose_new*100)/trials]
    ])

results_array = np.array(results)

fig, ax = plt.subplots(figsize=(10, 6))

for i, player_type in enumerate(['Conservative', 'Switcher', 'Newcomer']):
    ax.plot(results_array[:, i, 0], results_array[:, i, 1], label=f'{player_type} Win %')
ax.set_title('Win by player type and number of doors')
ax.set_xlabel('Number of doors')
ax.set_ylabel('Percentage')
ax.legend()
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from tqdm import tqdm
import matplotlib.pyplot as plt

trials = 1000
max_doors = 100
results = []

for num_doors in tqdm(range(3, max_doors + 1, 10), desc='Number of doors'):
    for doors_to_open in range(1, num_doors - 1, 10):
        win_cons = 0
        lose_cons = 0
        win_swi = 0
        lose_swi = 0
        win_new = 0
        lose_new = 0
        trial = []
        
        for i in range(trials):
            doors = np.zeros(num_doors, dtype=int)
            doors[np.random.randint(0, num_doors)] = 1
            trial.append(doors)
        
        for doors in trial:
            conservative_choice = np.random.randint(0, num_doors)
            if doors[conservative_choice] == 1:
                win_cons += 1
            else:
                lose_cons += 1
        
            available_doors = [i for i in range(num_doors) if doors[i] == 0 and i != conservative_choice]
            opened_N_door = np.random.choice(available_doors, size=doors_to_open, replace=False)
            other_doors = [i for i in range(num_doors) if i not in opened_N_door and i != conservative_choice]
            closed_doors = [conservative_choice] + other_doors
            if len(other_doors) > 0:
                switcher = other_doors[0]
                if doors[switcher] == 1:
                    win_swi += 1
                else:
                    lose_swi += 1

            newcomer = np.random.choice(closed_doors)
            if doors[newcomer] == 1:
                win_new += 1
            else:
                lose_new += 1
        
        results.append([
            [num_doors, doors_to_open, (win_cons*100)/trials, (lose_cons*100)/trials],
            [num_doors, doors_to_open, (win_swi*100)/trials, (lose_swi*100)/trials],
            [num_doors, doors_to_open, (win_new*100)/trials, (lose_new*100)/trials]
        ])

results_array = np.array(results)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

for i, player_type in enumerate(['Conservative', 'Switcher', 'Newcomer']):
    ax.plot_trisurf(results_array[:, i, 0], results_array[:, i, 1], results_array[:, i, 2], label=f'{player_type} Win %')

ax.set_title('Win percentages by player type, number of doors, and number of doors opened')
ax.set_xlabel('Number of doors')
ax.set_ylabel('Number of doors opened')
ax.set_zlabel('Win Percentage')
ax.legend()
plt.show()
# Out:
# Number of doors:   0%|          | 0/10 [00:00<?, ?it/s]
# Number of doors: 100%|██████████| 10/10 [00:14<00:00,  1.44s/it]
